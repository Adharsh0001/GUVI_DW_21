# %% [markdown]
# <a href="https://colab.research.google.com/github/Adharsh0001/GUVI_DW_21/blob/main/Engine_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
A = pd.read_csv("https://raw.githubusercontent.com/Adharsh0001/GUVI_DW_21/main/Engine%20Data.csv")
Speed = A.iloc[:,3]
Torque = A.iloc[:,4]
Speed_df = pd.DataFrame(Speed)
Torque_df = pd.DataFrame(Torque)
print(A)
#Speed.hist(bins=10)
A.plot.line(y ="SPEED" )
A.plot.line(y ="TORQUE" )
# Out:
#        Sr No  Rec.Index                TimeStamp  SPEED  TORQUE  THROTTLEFB  \
# 0          1          1  19/08/2022 21:10:06:885    900    2.31         0.0
# 1          2          2  19/08/2022 21:10:06:985    900    2.31         0.0
# 2          3          3   19/08/2022 21:10:07:85    900    2.32         0.0
# 3          4          4  19/08/2022 21:10:07:185    900    2.34         0.0
# 4          5          5  19/08/2022 21:10:07:285    900    2.36         0.0
# ...      ...        ...                      ...    ...     ...         ...
# 12422  12423      12423  19/08/2022 21:30:44:883    -35  -88.44         0.0
# 12423  12424      12424  19/08/2022 21:30:44:883    -56  -65.00         0.0
# 12424  12425      12425  19/08/2022 21:30:44:883    -12   10.54         0.0
# 12425  12426      12426  19/08/2022 21:30:44:883     33   53.97         0.0
# 12426  12427      12427  19/08/2022 21:30:44:883     37   33.46         0.0
#
# ...

# %%
A.shape
# Out:
# (12427, 11)

# %%
print(A.drop(columns="RT_StepIndex",inplace=True))
# Out:
# None

# %%
S_T = Speed_df.join(Torque_df)
S_T
# Out:
#        SPEED  TORQUE
# 0        900    2.31
# 1        900    2.31
# 2        900    2.32
# 3        900    2.34
# 4        900    2.36
# ...      ...     ...
# 12422    -35  -88.44
# 12423    -56  -65.00
# 12424    -12   10.54
# 12425     33   53.97
# 12426     37   33.46
#
# [12427 rows x 2 columns]

# %%
S_T.plot.line(y =["SPEED","TORQUE"] )
